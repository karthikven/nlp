# %%
import numpy as np

x = []
for line in open("data_2d.csv"):
    row = line.split(',')
    sample = [float(i) for i in row]
    x.append(sample)
x = np.array(x)
x
# Out:
# array([[1.79302012e+01, 9.45205920e+01, 3.20259530e+02],
#        [9.71446972e+01, 6.95932820e+01, 4.04634472e+02],
#        [8.17759008e+01, 5.73764810e+00, 1.81485108e+02],
#        [5.58543424e+01, 7.03259017e+01, 3.21773638e+02],
#        [4.93665500e+01, 7.51140402e+01, 3.22465486e+02],
#        [3.19270247e+00, 2.92562989e+01, 9.46188109e+01],
#        [4.92007841e+01, 8.61444385e+01, 3.56348093e+02],
#        [2.18828039e+01, 4.68415052e+01, 1.81653769e+02],
#        [7.95098627e+01, 8.73973555e+01, 4.23557743e+02],
#        [8.81538875e+01, 6.52056419e+01, 3.69229245e+02],
#        [6.07438543e+01, 9.99576339e+01, 4.27605804e+02],
#        [6.74155819e+01, 5.03683096e+01, 2.92471822e+02],
#        [4.83181158e+01, 9.91289531e+01, 3.95529811e+02],
#        [2.88299720e+01, 8.71849489e+01, 3.19031348e+02],
#        [4.38537427e+01, 6.44736391e+01, 2.87428144e+02],
#        [2.53136941e+01, 8.35452943e+01, 2.92768909e+02],
# ...

# %%
x.shape
# Out:
# (100, 3)

# %%
import pandas as pd

input_file = pd.read_csv('data_2d.csv', header = None)
input_file.head()
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486

# %%
type(input_file)
# Out:
# pandas.core.frame.DataFrame

# %%
input_file[2]
# Out:
# 0     320.259530
# 1     404.634472
# 2     181.485108
# 3     321.773638
# 4     322.465486
#          ...
# 95    336.876154
# 96    438.460586
# 97    355.900287
# 98    284.834637
# 99    168.034401
# Name: 2, Length: 100, dtype: float64

# %%
input_file.iloc[5]
# Out:
# 0     3.192702
# 1    29.256299
# 2    94.618811
# Name: 5, dtype: float64

# %%
input_file.ix[5]
# Out:
# /Users/karthikvenkatesh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 0     3.192702
# 1    29.256299
# 2    94.618811
# Name: 5, dtype: float64

# %%
input_file[input_file[0] < 93]
# Out:
#             0          1           2
# 0   17.930201  94.520592  320.259530
# 2   81.775901   5.737648  181.485108
# 3   55.854342  70.325902  321.773638
# 4   49.366550  75.114040  322.465486
# 5    3.192702  29.256299   94.618811
# ..        ...        ...         ...
# 95  46.456779  82.000171  336.876154
# 96  77.130301  95.188759  438.460586
# 97  68.600608  72.571181  355.900287
# 98  41.693887  69.241126  284.834637
# 99   4.142669  52.254726  168.034401
#
# [89 rows x 3 columns]

# %%
input_file[0] < 93
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: 0, Length: 100, dtype: bool

# %%
# load the 'international-airline-passenger.csv' file using pandas

col_head = ['Month', 'Totals']
airline = pd.read_csv('international-airline-passengers.csv', header = 0, names = col_head, skiprows = [145,146,147,148])
airline.head()
# Out:
#      Month  Totals
# 0  1949-01     112
# 1  1949-02     118
# 2  1949-03     132
# 3  1949-04     129
# 4  1949-05     121

# %%
airline
# Out:
#        Month  Totals
# 0    1949-01     112
# 1    1949-02     118
# 2    1949-03     132
# 3    1949-04     129
# 4    1949-05     121
# ..       ...     ...
# 139  1960-08     606
# 140  1960-09     508
# 141  1960-10     461
# 142  1960-11     390
# 143  1960-12     432
#
# [144 rows x 2 columns]

# %%
airline[airline['Totals'] > 400]
# Out:
#        Month  Totals
# 90   1956-07     413
# 91   1956-08     405
# 101  1957-06     422
# 102  1957-07     465
# 103  1957-08     467
# 104  1957-09     404
# 113  1958-06     435
# 114  1958-07     491
# 115  1958-08     505
# 116  1958-09     404
# 122  1959-03     406
# 124  1959-05     420
# 125  1959-06     472
# 126  1959-07     548
# 127  1959-08     559
# 128  1959-09     463
# 129  1959-10     407
# 131  1959-12     405
# 132  1960-01     417
# 134  1960-03     419
# 135  1960-04     461
# 136  1960-05     472
# 137  1960-06     535
# 138  1960-07     622
# 139  1960-08     606
# 140  1960-09     508
# 141  1960-10     461
# 143  1960-12     432

# %%
airline['ones'] = 1

# %%
airline
# Out:
#        Month  Totals  ones
# 0    1949-01     112     1
# 1    1949-02     118     1
# 2    1949-03     132     1
# 3    1949-04     129     1
# 4    1949-05     121     1
# ..       ...     ...   ...
# 139  1960-08     606     1
# 140  1960-09     508     1
# 141  1960-10     461     1
# 142  1960-11     390     1
# 143  1960-12     432     1
#
# [144 rows x 3 columns]

# %%
from datetime import datetime
airline['dt'] = airline.apply(lambda row: datetime.strptime(row['Month'], "%Y-%m"), axis = 1)
airline
# Out:
#        Month  Totals  ones         dt
# 0    1949-01     112     1 1949-01-01
# 1    1949-02     118     1 1949-02-01
# 2    1949-03     132     1 1949-03-01
# 3    1949-04     129     1 1949-04-01
# 4    1949-05     121     1 1949-05-01
# ..       ...     ...   ...        ...
# 139  1960-08     606     1 1960-08-01
# 140  1960-09     508     1 1960-09-01
# 141  1960-10     461     1 1960-10-01
# 142  1960-11     390     1 1960-11-01
# 143  1960-12     432     1 1960-12-01
#
# [144 rows x 4 columns]

# %%
# joins
t1 = pd.read_csv('table1.csv')
t2 = pd.read_csv('table2.csv')

t3 = pd.merge(t1,t2, how = 'left', on = 'user_id')
t3
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1

# %%
t_np = t3.values
t_np
# Out:
# array([[1, 'alice@gmail.com', 20, 1, 1],
#        [1, 'alice@gmail.com', 20, 2, 0],
#        [1, 'alice@gmail.com', 20, 5, 0],
#        [2, 'bob@gmail.com', 25, 3, 0],
#        [2, 'bob@gmail.com', 25, 4, 1],
#        [2, 'bob@gmail.com', 25, 1, 0],
#        [3, 'carol@gmail.com', 30, 2, 0],
#        [3, 'carol@gmail.com', 30, 1, 0],
#        [3, 'carol@gmail.com', 30, 3, 0],
#        [3, 'carol@gmail.com', 30, 4, 0],
#        [3, 'carol@gmail.com', 30, 5, 1]], dtype=object)
